# %% [markdown]
# # EDA and Phase Calibration
#
# This notebook verifies:
# 1. Flux distributions for quiet vs flare periods to set thresholds.
# 2. Determine `phase_frac_pre` and `phase_frac_gradual`.
# 3. Verify GOES cross-calibration $R^2 > 0.80$ using log-space Huber Regressor.

# %%
import sys
sys.path.append('..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from src.preprocessing.cross_calibration import fit_goes_solexs_calibration
from src.preprocessing.physics_features import detect_solar_phase

# %%
# To run this, you need GOES data downloaded via `python scripts/goes_downloader.py`
# goes_df = pd.read_parquet("../data/raw/goes/goes_xrs_...parquet")
# solexs_df = ... (load from fits_reader)

# calibration = fit_goes_solexs_calibration(goes_df, solexs_df)
# print(calibration)
